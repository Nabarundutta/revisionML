# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabarundutta/revisionML/blob/main/RF1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples = 100,n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['c1','c2','c3','c4','c5'])
df.head()
# Out:
#          c1        c2        c3        c4        c5
# 0 -0.189427 -1.523285 -0.316496  0.751813 -0.107798
# 1 -2.775380  1.572419 -2.180187 -2.319068 -1.014198
# 2 -1.628166 -1.738201 -0.372748 -0.073117 -0.609634
# 3  0.454696  0.812850  0.875436  0.674166 -3.941170
# 4 -1.379815 -4.694699  0.611734 -0.731163 -1.440369

# %%
df['Target'] = y
df.head()
# Out:
#          c1        c2        c3        c4        c5  Target
# 0 -0.189427 -1.523285 -0.316496  0.751813 -0.107798       0
# 1 -2.775380  1.572419 -2.180187 -2.319068 -1.014198       1
# 2 -1.628166 -1.738201 -0.372748 -0.073117 -0.609634       0
# 3  0.454696  0.812850  0.875436  0.674166 -3.941170       1
# 4 -1.379815 -4.694699  0.611734 -0.731163 -1.440369       0

# %%
def sample_rows(df,p):
    return df.sample(int(p*df.shape[0]),replace=True)

# %%
def sample_features(df,p):
    cols = random.sample(df.columns.tolist()[:,-1],int(p*df.shape[1]-1))
    new_df = df['cols']
    new_df['Target'] = df['Target']
    return new_df

# %%
def sample_combined(df,rp,cp):
    new_df = sample_rows(df,rp)
    return sample_features(new_df,cp)

# %%
df1 = sample_rows(df,0.5)
df2 = sample_rows(df,0.1)
df3 = sample_rows(df,0.6)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
model1 = DecisionTreeClassifier()
model2 = DecisionTreeClassifier()
model3 = DecisionTreeClassifier()

# %%
df1.head()
# Out:
#           c1        c2        c3        c4        c5  Target
# 76  0.251641  2.407494 -4.345615  1.917255 -2.781068       0
# 81 -1.610522 -3.132126 -1.489357  0.254205 -3.727271       0
# 23 -1.148651 -3.482379 -0.590105 -0.979246 -2.150088       0
# 90 -2.169288  0.366203 -3.297660 -3.307849  0.091346       1
# 44 -2.768057  1.375827 -2.354032 -2.055828  0.166892       1

# %%
model1.fit(df1.iloc[:,:-1],df1.iloc[:,-1])
model2.fit(df2.iloc[:,:-1],df2.iloc[:,-1])
model3.fit(df3.iloc[:,:-1],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(model1)
# Out:
# [Text(0.3333333333333333, 0.875, 'x[1] <= -1.05\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.16666666666666666, 0.625, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.5, 0.625, 'x[3] <= 0.804\ngini = 0.328\nsamples = 29\nvalue = [6, 23]'),
#  Text(0.3333333333333333, 0.375, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.6666666666666666, 0.375, 'x[2] <= -0.28\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8333333333333334, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
plot_tree(model2)
# Out:
# [Text(0.5, 0.75, 'x[3] <= -0.47\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]')]

# %%
plot_tree(model3)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 0.165\ngini = 0.498\nsamples = 60\nvalue = [32, 28]'),
#  Text(0.3, 0.625, 'x[3] <= -0.885\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.2, 0.375, 'x[1] <= -1.971\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4, 0.375, 'gini = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(0.7, 0.625, 'x[3] <= 0.605\ngini = 0.35\nsamples = 31\nvalue = [7, 24]'),
#  Text(0.6, 0.375, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.8, 0.375, 'x[2] <= -0.822\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.7, 0.125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.9, 0.125, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]')]

# %%
df2
# Out:
#           c1        c2        c3        c4        c5  Target
# 63 -0.888048  0.818795 -1.628233 -1.300085  0.307747       1
# 60 -1.187926 -4.072537  0.416589 -0.218182 -1.361932       0
# 60 -1.187926 -4.072537  0.416589 -0.218182 -1.361932       0
# 42 -0.898352  2.039625 -1.782275  2.173440  0.260274       0
# 72 -1.098302  0.282141 -2.104746 -2.873164 -0.044769       1
# 73  0.004976 -1.950829 -1.692378  1.285284 -2.706272       0
# 47 -0.483162  0.476406 -0.617437 -0.722687 -2.182288       1
# 46 -0.651302  0.207852 -1.231766 -0.984426 -0.731854       1
# 9   0.352984 -0.478698 -1.712697 -2.234657 -0.409731       1
# 22 -2.326690 -2.968069 -0.571797  1.222035 -2.453033       0

# %%
model1.predict([[0.004976,	-1.950829	,-1.692378,	1.285284,	-2.706272	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model2.predict([[0.004976,	-1.950829	,-1.692378,	1.285284,	-2.706272	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model3.predict([[0.004976,	-1.950829	,-1.692378,	1.285284,	-2.706272	]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
