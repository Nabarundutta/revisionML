# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabarundutta/revisionML/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y,cmap='coolwarm')

plt.show()

# %%
def perceptron(X,y):
    X = np.insert(X,0,1,axis=1)
    lr = 0.1
    weights = np.ones(X.shape[1])
    for i in range(100):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]

    return weights[0],weights[1:]

# %%
def step(z):
  if(z>0):
    return 1
  else:
    return 0

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print(intercept_)
print(coef_)
# Out:
# 0.9
# [1.25938156 0.26978659]

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,50)
y_input = m*x_input + b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')
plt.ylim(-3,3)
# Out:
# (-3.0, 3.0)

# %%
def perceptron1(X,y):
    X = np.insert(X,0,1,axis =1)
    w = np.ones(X.shape[1])
    lr = 0.1
    epoch = 100

    for i in range(epoch):
        j = np.random.randint(0,100)
        y_hat = roundof(np.dot(X[j],w))
        w = w + lr*(y[j]-y_hat)*X[j]

    return w[0],w[1:]

# %%
def roundof(z):
  if(z>0):
    return 1
  else:
    return 0

# %%
intercept_1,coef_1 = perceptron1(X,y)

# %%
print(intercept_1)
print(coef_1)
# Out:
# 0.9
# [1.36421891 0.17223796]

# %%
m = -coef_1[0]/coef_1[1]
b = -intercept_1/coef_1[1]

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input +b

# %%
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter')
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.ylim(-3,3)
# Out:
# (-3.0, 3.0)
