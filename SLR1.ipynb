# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabarundutta/revisionML/blob/main/SLR1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('homeprices.csv')
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
import matplotlib.pyplot as plt
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='red')

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
df1 = pd.read_csv('home.csv')
df1.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
df1.fillna(df1['bedrooms'].median(),inplace = True)

# %%
df1
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
model1 = LinearRegression()
model1.fit(df1[['area','bedrooms','age']],df1.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
model1.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
model1.intercept_
# Out:
# 221323.00186540396
