# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabarundutta/revisionML/blob/main/VotingRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mobile.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        807 non-null    float64
#  1   RAM            807 non-null    float64
#  2   ROM            807 non-null    float64
#  3   Mobile_Size    807 non-null    float64
#  4   Primary_Cam    807 non-null    int64
#  5   Selfi_Cam      807 non-null    float64
#  6   Battery_Power  807 non-null    int64
#  7   Price          807 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 50.6 KB

# %%
df.head()
# Out:
#    Ratings  RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power  \
# 0      4.3  4.0  128.0         6.00           48       13.0           4000
# 1      3.4  6.0   64.0         4.50           48       12.0           4000
# 2      4.3  4.0    4.0         4.50           64       16.0           4000
# 3      4.4  6.0   64.0         6.40           48       15.0           3800
# 4      4.5  6.0  128.0         6.18           35       15.0           3800
#
#    Price
# 0  24999
# 1  15999
# 2  15000
# 3  18999
# 4  18999

# %%
X = df.drop('Price',axis=1)

# %%
X
# Out:
#      Ratings   RAM    ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# 0        4.3   4.0  128.0         6.00           48       13.0           4000
# 1        3.4   6.0   64.0         4.50           48       12.0           4000
# 2        4.3   4.0    4.0         4.50           64       16.0           4000
# 3        4.4   6.0   64.0         6.40           48       15.0           3800
# 4        4.5   6.0  128.0         6.18           35       15.0           3800
# ..       ...   ...    ...          ...          ...        ...            ...
# 802      3.8   6.0   32.0         4.54           48       12.0           2800
# 803      4.1   8.0   64.0         4.54           64        8.0           2500
# 804      4.4   3.0   32.0         6.20           48        1.0           3800
# 805      3.7  10.0   32.0         4.50           64        8.0           3500
# 806      3.5   6.0   32.0         4.50           64       15.0           1050
#
# [807 rows x 7 columns]

# %%
y = df.Price

# %%
y.head()
# Out:
# 0    24999
# 1    15999
# 2    15000
# 3    18999
# 4    18999
# Name: Price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svr = SVR()

# %%
estimators = [
    ('lr',lr),
    ('dt',dt),
    ('svr',svr)
]

# %%
for estimator in estimators:
    scores = cross_val_score(estimator[1],X,y,scoring='r2',cv=10)
    print(estimator[0],np.round(np.mean(scores),2))
# Out:
# lr 0.45
# dt 0.82
# svr -0.34

# %%
from sklearn.ensemble import VotingRegressor
vr = VotingRegressor(estimators = estimators)
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print(np.round(np.mean(scores),2))
# Out:
# 0.63

# %%
scores
# Out:
# array([0.54071319, 0.388247  , 0.65083336, 0.59515878, 0.80725258,
#        0.65297472, 0.64829785, 0.78578041, 0.65679576, 0.61897207])

# %%
# np.mean(scores)
scores.mean()
# Out:
# 0.6345025728350084

# %%
from sklearn.ensemble import VotingRegressor
# Convert the set to a list of tuples
estimators_list = list(estimators)
vr = VotingRegressor(estimators=estimators_list)  # Pass a list to VotingRegressor
scores = cross_val_score(vr,X,y,scoring='r2',cv=10)
print(np.round(np.mean(scores),2))
# Out:
# 0.63
